# %% [markdown]
# Link from kaggle
# https://www.kaggle.com/datasets/amitanshjoshi/spotify-1million-tracks
#
# Prever a popularidade da música
# ---
# Predict song popularity

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# Due to the data set having more than 50mb the link to download it is in the file and in the Read me

# %%
data = pd.read_csv('spotify_data.csv')
data.shape
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1159764 entries, 0 to 1159763
# Data columns (total 20 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1159764 non-null  int64
#  1   artist_name       1159749 non-null  object
#  2   track_name        1159763 non-null  object
#  3   track_id          1159764 non-null  object
#  4   popularity        1159764 non-null  int64
#  5   year              1159764 non-null  int64
#  6   genre             1159764 non-null  object
#  7   danceability      1159764 non-null  float64
#  8   energy            1159764 non-null  float64
#  9   key               1159764 non-null  int64
#  10  loudness          1159764 non-null  float64
#  11  mode              1159764 non-null  int64
#  12  speechiness       1159764 non-null  float64
#  13  acousticness      1159764 non-null  float64
#  14  instrumentalness  1159764 non-null  float64
# ...

# %%
data.columns
data.head(5)
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2012  acoustic         0.483   0.303    4   -10.058     1
# 1          50  2012  acoustic         0.572   0.454    3   -10.286     1
# 2          57  2012  acoustic         0.409   0.234    3   -13.711     1
# 3          58  2012  acoustic         0.392   0.251   10    -9.845     1
# 4          54  2012  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
data = data.drop(columns=['track_id', 'artist_name', 'track_name'])

# %% [markdown]
# Preparing data for Model

# %%
codificador = LabelEncoder()
data['genre'] = codificador.fit_transform(data['genre'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1159764 entries, 0 to 1159763
# Data columns (total 17 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1159764 non-null  int64
#  1   popularity        1159764 non-null  int64
#  2   year              1159764 non-null  int64
#  3   genre             1159764 non-null  int32
#  4   danceability      1159764 non-null  float64
#  5   energy            1159764 non-null  float64
#  6   key               1159764 non-null  int64
#  7   loudness          1159764 non-null  float64
#  8   mode              1159764 non-null  int64
#  9   speechiness       1159764 non-null  float64
#  10  acousticness      1159764 non-null  float64
#  11  instrumentalness  1159764 non-null  float64
#  12  liveness          1159764 non-null  float64
#  13  valence           1159764 non-null  float64
#  14  tempo             1159764 non-null  float64
# ...

# %%
y = data['popularity']
x = data.drop(['popularity', 'Unnamed: 0'], axis=1)

x_training, x_test, y_training, y_test = train_test_split(x, y, test_size = 0.4)

# %%
#Arvore de decisão
decision_tree = RandomForestClassifier()
#KNN
knn_model = KNeighborsClassifier()

decision_tree.fit(x_training, y_training)
knn_model.fit(x_training, y_training)
# Out:
# KNeighborsClassifier()

# %%
decision_tree_prediction = decision_tree.predict(x_test)
knn_model_prediction = knn_model.predict(x_test.to_numpy())
print(f'deciciosn tree acc is: ', accuracy_score(y_test, decision_tree_prediction))
print(f'knn model acc is: ', accuracy_score(y_test, knn_model_prediction))
# Out:
# C:\Users\flpyo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# deciciosn tree acc is:  0.15876061098584626
# knn model acc is:  0.08933059714683578

# %% [markdown]
# Utilizando esses dois modelos pode-se observar que estes não possuem uma acurácia estatística confiavel, ficando com 15,89% do modelo de arvore de decisão e aproximadamente 9% no modelo KMM
